# %%
import pandas as pd
import numpy as np
import json

# %%
with open("road_data.json") as f:
    data=json.load(f)

df=pd.DataFrame(data)

# %%
df.head()
# Out:
#        length  road_type   elevation  flood_reports  traffic_speed  is_night  \
# 0  240.323917          0  259.565511             10      59.464298         1
# 1  603.380030          0  212.232796              4      31.432445         0
# 2  567.749150          2  241.808170              5      29.685985         0
# 3   94.802650          2  249.088089              1      56.135346         0
# 4  649.088803          0  235.226807              7      25.842951         1
#
#    risk_score
# 0    0.356902
# 1    0.485537
# 2    0.617939
# 3    0.076875
# 4    0.673394

# %%
df.shape
# Out:
# (5000, 7)

# %%
from sklearn.model_selection import train_test_split

X=df.drop("risk_score",axis=1)
y=df["risk_score"]

# %%
X.sample(5)
# Out:
#           length  road_type   elevation  flood_reports  traffic_speed  \
# 3293  674.183759          1  207.784558              0      42.094353
# 4374  257.463757          0  251.627334              6      46.017041
# 1293  153.519396          0  259.753281              5      27.392196
# 376   281.382871          2  208.298273              4      46.512332
# 3926  628.356213          2  252.985135              9      44.493175
#
#       is_night
# 3293         0
# 4374         1
# 1293         0
# 376          0
# 3926         1

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(n_estimators=130,max_depth=10,random_state=10)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=130, random_state=10)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_test, y_pred)
print(f"Accuracy: {rmse}")
# Out:
# Accuracy: 0.12036271009155455

# %%
import joblib
joblib.dump(model,"risk_model.pkl")
print("Model saved")
# Out:
# Model saved
